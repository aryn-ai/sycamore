# %%
import sycamore

# s3 file path to the SortBenchmark dataset
paths = "https://www.faa.gov/sites/faa.gov/files/2022-12/FTW95FA129.pdf"
#paths = "/Users/moe/Downloads/sort.pdf"

# Initializng sycamore which also initializes Ray underneath
context = sycamore.init()

# Creating a DocSet
docset = context.read.binary(paths, parallelism=1, binary_format="pdf")

# %%
from sycamore.transforms.partition import UnstructuredPdfPartitioner

# We are using UnstructuredPdfPartitioner to partion the documents.
# Sycamore supports pluggable partitioners for different formats.
docset = docset.partition(partitioner=UnstructuredPdfPartitioner())

# %%
from sycamore.transforms.schema import OpenAISchema, OpenAIPropertyExtractor
from sycamore.llms import OpenAIModels, OpenAI
import os

openai = OpenAI(OpenAIModels.GPT_3_5_TURBO.value, api_key=os.environ.get("OPENAI_API_KEY"))

docset = docset.extract_schema(
            schema_extractor=OpenAISchema("AircraftAccident", llm=openai, num_of_elements=35)
        )

# %%
schema = docset.take(1)[0].properties["_schema"]
# Out:
# 2023-11-14 13:49:38,184	INFO streaming_executor.py:93 -- Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary->Map(BinaryScan._to_document)->Map(partition)->Map(extract_schema)] -> LimitOperator[limit=1]
# 2023-11-14 13:49:38,185	INFO streaming_executor.py:94 -- Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# 2023-11-14 13:49:38,185	INFO streaming_executor.py:96 -- Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# Running 0:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ntsb_path = "/Users/moe/Downloads/NTSB"
ntsb_docs = context.read.binary(ntsb_path, parallelism=1, binary_format="pdf")
ntsb_docs = ntsb_docs.partition(partitioner=UnstructuredPdfPartitioner())

def update_schema(doc):
    doc.properties["_schema"] = schema
    doc.properties["_schema_class"] = "AircraftAccident"
    return doc

ntsb_docs = ntsb_docs.limit(5).map(update_schema).extract_properties(
            property_extractor=OpenAIPropertyExtractor(llm=openai, num_of_elements=20)
        )
ntsb_docs.show()
# Out:
# 2023-11-14 13:49:43,061	INFO streaming_executor.py:93 -- Executing DAG InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary->Map(BinaryScan._to_document)->Map(partition)] -> LimitOperator[limit=5] -> TaskPoolMapOperator[Map(update_schema)->Map(extract_properties)] -> LimitOperator[limit=20]
# 2023-11-14 13:49:43,061	INFO streaming_executor.py:94 -- Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# 2023-11-14 13:49:43,062	INFO streaming_executor.py:96 -- Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# {'doc_id': 'b8223248-8337-11ee-ae37-9ec0ee1f5eae',
#  'type': 'pdf',
#  'binary_representation': b'<98716 bytes>',
#  'properties': {'path': '/Users/moe/Downloads/NTSB/FTW95FA129.pdf',
#                 '_schema': {'type': 'object',
#                             'properties': {'accidentNumber': {'type': 'string'},
#                                            'location': {'type': 'string'},
#                                            'dateAndTime': {'type': 'string',
#                                                            'format': 'date-time'},
#                                            'aircraft': {'type': 'string'},
#                                            'definingEvent': {'type': 'string'},
#                                            'flightConductedUnder': {'type': 'string'},
#                                            'probableCause': {'type': 'string'},
#                                            'registration': {'type': 'string'},
#                                            'aircraftDamage': {'type': 'string'},
#                                            'injuries': {'type': 'string'},
#                                            'occurrence1': {'type': 'string'},
#                                            'occurrence2': {'type': 'string'},
#                                            'factualInformation': {'type': 'string'}}},
#                 '_schema_class': 'AircraftAccident',
#                 'entity': {'accidentNumber': 'FTW95FA129',
#                            'location': 'ARDMORE, OK',
#                            'dateAndTime': '1995-03-02T08:15:00Z',
#                            'aircraft': 'CESSNA 208B',
#                            'definingEvent': 'STRUCTURAL ICE ACCUMULATED ON THE '
#                                             'AIRPLANE',
#                            'flightConductedUnder': 'Part 135: Air Taxi & '
#                                                    'Commuter - Non-scheduled',
#                            'probableCause': "THE PILOT'S CONTINUED FLIGHT INTO "
#                                             'ADVERSE WEATHER CONDITIONS. '
#                                             'FACTORS WERE THE ICING CONDITIONS '
#                                             'PREVAILING AT THE DESTINATION '
#                                             "AIRPORT, AND THE PILOT'S "
#                                             'INABILITY TO MAINTAIN VISUAL '
#                                             'LOOKOUT DUE TO WINDSHIELD ICING.',
#                            'registration': 'N9448B',
#                            'aircraftDamage': 'None',
#                            'injuries': 'None',
#                            'occurrence1': 'None',
#                            'occurrence2': 'None',
#                            'factualInformation': 'STRUCTURAL ICE ACCUMULATED '
#                                                  'ON THE AIRPLANE AT A RAPID '
#                                                  'RATE WHILE THE PILOT WAS '
#                                                  'EXECUTING A PROCEDURE TURN '
#                                                  'DURING AN NDB APPROACH TO '
#                                                  'HIS DESTINATION AIRPORT. THE '
#                                                  'PILOT APPLIED MAXIMUM '
#                                                  'AVAILABLE POWER BUT WAS '
#                                                  'UNABLE TO ARREST THE RATE OF '
#                                                  'DESCENT. THE PILOT '
#                                                  'MAINTAINED 110 KNOTS DURING '
#                                                  'THE APPROACH AND AFTER '
#                                                  'BREAKING OUT INTO VISUAL '
#                                                  'CONDITIONS ELECTED TO '
#                                                  'PERFORM A FORCED LANDING IN '
#                                                  'AN OPEN FIELD 2 MILES SHORT '
#                                                  'OF THE DESTINATION AIRPORT. '
#                                                  'THE PILOT WAS UNABLE TO '
#                                                  'ARREST HIS DESCENT AND THE '
#                                                  'AIRPLANE IMPACTED THE GROUND '
#                                                  'IN A 5 DEGREE NOSE DOWN '
#                                                  'ATTITUDE. THE PILOT ALSO '
#                                                  'STATED THAT HIS FORWARD '
#                                                  'VISIBILITY WAS COMPLETELY '
#                                                  'OBSCURED BY THE ACCUMULATION '
#                                                  'OF CLEAR ICE ON THE '
#                                                  'WINDSHIELD. THE AIRPORT '
#                                                  'MANAGER INFORMED THE PILOT '
#                                                  'THAT FREEZING DRIZZLE WAS '
#                                                  'PRESENT AT THE AIRPORT WHEN '
#                                                  'THE PILOT CALLED THE UNICOM '
#                                                  'DURING THE INITIAL PORTION '
#                                                  'OF THE INSTRUMENT '
#                                                  'APPROACH.'}},
#  'elements': [{'type': 'Title',
#                'binary_representation': b'National Transportation Safety Board'
#                                         b' Aviation Accident Final Report',
#                'text_representation': 'National Transportation Safety Board '
#                                       'Aviation Accident Final Report',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '9e18ced51fa7b44b309f85272d9da40d'},
#                'bbox': (0.29237254771241833,
#                         0.09456691801767676,
#                         0.8027254888888888,
#                         0.1436830791540404)},
#               {'type': 'Title',
#                'binary_representation': b'Location:',
#                'text_representation': 'Location:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'bbdffe25dc7d80cfa441b069d0c54c38'},
#                'bbox': (0.08823529411764706,
#                         0.194688130770202,
#                         0.15982026143790853,
#                         0.20731439339646462)},
#               {'type': 'Title',
#                'binary_representation': b'ARDMORE, OK',
#                'text_representation': 'ARDMORE, OK',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '7e17c545f5e098b47f55547e9f74d8dd'},
#                'bbox': (0.29616013071895425,
#                         0.194688130770202,
#                         0.3975326797385621,
#                         0.20731439339646462)},
#               {'type': 'Title',
#                'binary_representation': b'Date & Time:',
#                'text_representation': 'Date & Time:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'bec3889368a0ce8bb5dcd32bfa56eadb'},
#                'bbox': (0.08823529411764706,
#                         0.21944949448232326,
#                         0.18898692810457515,
#                         0.23207575710858588)},
#               {'type': 'UncategorizedText',
#                'binary_representation': b'03/02/1995, 0815 CST',
#                'text_representation': '03/02/1995, 0815 CST',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'bec3889368a0ce8bb5dcd32bfa56eadb',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'd3b6d91801e0e44666f149e94046bbcb'},
#                'bbox': (0.29616013071895425,
#                         0.21944949448232326,
#                         0.46400326797385627,
#                         0.23207575710858588)},
#               {'type': 'Title',
#                'binary_representation': b'Aircraft:',
#                'text_representation': 'Aircraft:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '8e0dc5b9e885131e6d3da4842bf34d03'},
#                'bbox': (0.08823529411764706,
#                         0.24421085819444438,
#                         0.1530065359477124,
#                         0.256837120820707)},
#               {'type': 'Title',
#                'binary_representation': b'CESSNA 208B',
#                'text_representation': 'CESSNA 208B',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'e93e5cb0ddc3dfc7fdc6bf34919dd219'},
#                'bbox': (0.29616013071895425,
#                         0.24421085819444438,
#                         0.39034313725490194,
#                         0.256837120820707)},
#               {'type': 'Title',
#                'binary_representation': b'Defining Event:',
#                'text_representation': 'Defining Event:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'cb1092b381ae82caab4cf67aae853e6a'},
#                'bbox': (0.08823529411764706,
#                         0.2689722219065656,
#                         0.2057516339869281,
#                         0.28159848453282826)},
#               {'type': 'Title',
#                'binary_representation': b'Flight Conducted Under:',
#                'text_representation': 'Flight Conducted Under:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'fe430138113acffbdc9d0aff0b6a4633'},
#                'bbox': (0.08823529411764706,
#                         0.2937335856186869,
#                         0.2759967320261438,
#                         0.3063598482449495)},
#               {'type': 'Title',
#                'binary_representation': b'Part 135: Air Taxi & Commuter - Non-'
#                                         b'scheduled',
#                'text_representation': 'Part 135: Air Taxi & Commuter - '
#                                       'Non-scheduled',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '263767306f45f439b7c8cdb06462622f'},
#                'bbox': (0.29616013071895425,
#                         0.2937335856186869,
#                         0.6458333333333331,
#                         0.3063598482449495)},
#               {'type': 'Title',
#                'binary_representation': b'Analysis',
#                'text_representation': 'Analysis',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'e70d8eb9050021ad51462409f6024d41'},
#                'bbox': (0.08823529411764706,
#                         0.34792046363636364,
#                         0.18740196078431373,
#                         0.3668598575757575)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'STRUCTURAL ICE ACCUMULATED ON THE AI'
#                                         b'RPLANE AT A RAPID RATE WHILE THE PIL'
#                                         b'OT WAS EXECUTING A PROCEDURE TURN DU'
#                                         b'RING AN NDB APPROACH TO HIS DESTINAT'
#                                         b'ION AIRPORT. THE PILOT APPLIED MAXIM'
#                                         b'UM AVAILABLE POWER BUT WAS UNABLE TO'
#                                         b' ARREST THE RATE OF DESCENT. THE PIL'
#                                         b'OT MAINTAINED 110 KNOTS DURING THE A'
#                                         b'PPROACH AND AFTER BREAKING OUT INTO '
#                                         b'VISUAL CONDITIONS ELECTED TO PERFORM'
#                                         b' A FORCED LANDING IN AN OPEN FIELD 2'
#                                         b' MILES SHORT OF THE DESTINATION AIRP'
#                                         b'ORT. THE PILOT WAS UNABLE TO ARREST '
#                                         b'HIS DESCENT AND THE AIRPLANE IMPACTE'
#                                         b'D THE GROUND IN A 5 DEGREE NOSE DOWN'
#                                         b' ATTITUDE. THE PILOT ALSO STATED THA'
#                                         b'T HIS FORWARD VISIBILITY WAS COMPLET'
#                                         b'ELY OBSCURED BY THE ACCUMULATION OF '
#                                         b'CLEAR ICE ON THE WINDSHIELD. THE AIR'
#                                         b'PORT MANAGER INFORMED THE PILOT THAT'
#                                         b' FREEZING DRIZZLE WAS PRESENT AT THE'
#                                         b' AIRPORT WHEN THE PILOT CALLED THE U'
#                                         b'NICOM DURING THE INITIAL PORTION OF '
#                                         b'THE INSTRUMENT APPROACH.',
#                'text_representation': 'STRUCTURAL ICE ACCUMULATED ON THE '
#                                       'AIRPLANE AT A RAPID RATE WHILE THE '
#                                       'PILOT WAS EXECUTING A PROCEDURE TURN '
#                                       'DURING AN NDB APPROACH TO HIS '
#                                       'DESTINATION AIRPORT. THE PILOT APPLIED '
#                                       'MAXIMUM AVAILABLE POWER BUT WAS UNABLE '
#                                       'TO ARREST THE RATE OF DESCENT. THE '
#                                       'PILOT MAINTAINED 110 KNOTS DURING THE '
#                                       'APPROACH AND AFTER BREAKING OUT INTO '
#                                       'VISUAL CONDITIONS ELECTED TO PERFORM A '
#                                       'FORCED LANDING IN AN OPEN FIELD 2 MILES '
#                                       'SHORT OF THE DESTINATION AIRPORT. THE '
#                                       'PILOT WAS UNABLE TO ARREST HIS DESCENT '
#                                       'AND THE AIRPLANE IMPACTED THE GROUND IN '
#                                       'A 5 DEGREE NOSE DOWN ATTITUDE. THE '
#                                       'PILOT ALSO STATED THAT HIS FORWARD '
#                                       'VISIBILITY WAS COMPLETELY OBSCURED BY '
#                                       'THE ACCUMULATION OF CLEAR ICE ON THE '
#                                       'WINDSHIELD. THE AIRPORT MANAGER '
#                                       'INFORMED THE PILOT THAT FREEZING '
#                                       'DRIZZLE WAS PRESENT AT THE AIRPORT WHEN '
#                                       'THE PILOT CALLED THE UNICOM DURING THE '
#                                       'INITIAL PORTION OF THE INSTRUMENT '
#                                       'APPROACH.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'e70d8eb9050021ad51462409f6024d41',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '752c0984039c6e6248f1ceba75b6e77a'},
#                'bbox': (0.08823529411764706,
#                         0.3840757569065656,
#                         0.915666666666667,
#                         0.6058181725757574)},
#               {'type': 'Title',
#                'binary_representation': b'Probable Cause and Findings',
#                'text_representation': 'Probable Cause and Findings',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '7433a1a90502bfa6aa5babd7c5fa98cd'},
#                'bbox': (0.08823529411764706,
#                         0.6315972276136363,
#                         0.4158823529411764,
#                         0.6505366215530303)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'The National Transportation Safety B'
#                                         b'oard determines the probable cause(s'
#                                         b") of this accident to be: THE PILOT'"
#                                         b'S CONTINUED FLIGHT INTO ADVERSE WEAT'
#                                         b'HER CONDITIONS. FACTORS WERE THE ICI'
#                                         b'NG CONDITIONS PREVAILING AT THE DEST'
#                                         b"INATION AIRPORT, AND THE PILOT'S INA"
#                                         b'BILITY TO MAINTAIN VISUAL LOOKOUT DU'
#                                         b'E TO WINDSHIELD ICING.',
#                'text_representation': 'The National Transportation Safety '
#                                       'Board determines the probable cause(s) '
#                                       "of this accident to be: THE PILOT'S "
#                                       'CONTINUED FLIGHT INTO ADVERSE WEATHER '
#                                       'CONDITIONS. FACTORS WERE THE ICING '
#                                       'CONDITIONS PREVAILING AT THE '
#                                       "DESTINATION AIRPORT, AND THE PILOT'S "
#                                       'INABILITY TO MAINTAIN VISUAL LOOKOUT '
#                                       'DUE TO WINDSHIELD ICING.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': '7433a1a90502bfa6aa5babd7c5fa98cd',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'f581a7d82af9e6f57bd45e4d15b11b27'},
#                'bbox': (0.08823529411764706,
#                         0.6677525208838384,
#                         0.9128431372549021,
#                         0.7345517593560605)},
#               {'type': 'Title',
#                'binary_representation': b'Page 1 of 7',
#                'text_representation': 'Page 1 of 7',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'f5c77a3dd7cce5f41439a694d6ed7c49'},
#                'bbox': (0.08823529411764706,
#                         0.946191936540404,
#                         0.17790686274509804,
#                         0.960080825429293)},
#               {'type': 'Title',
#                'binary_representation': b'Accident Number:',
#                'text_representation': 'Accident Number:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'bcef1e51eb7e28448e27313999f7292f'},
#                'bbox': (0.5755718954248366,
#                         0.194688130770202,
#                         0.713921568627451,
#                         0.20731439339646462)},
#               {'type': 'Title',
#                'binary_representation': b'FTW95FA129',
#                'text_representation': 'FTW95FA129',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': 'ae4ce48b0df4dd7a0f4fa1b6262818dc'},
#                'bbox': (0.7520424836601307,
#                         0.194688130770202,
#                         0.8450816993464051,
#                         0.20731439339646462)},
#               {'type': 'Title',
#                'binary_representation': b'Registration:',
#                'text_representation': 'Registration:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '572c0754cd50d02188f5e7a7830db183'},
#                'bbox': (0.5755718954248366,
#                         0.21944949448232326,
#                         0.6734640522875818,
#                         0.23207575710858588)},
#               {'type': 'UncategorizedText',
#                'binary_representation': b'N9448B',
#                'text_representation': 'N9448B',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': '572c0754cd50d02188f5e7a7830db183',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '31295298f14856ff628ee23debcc4b6d'},
#                'bbox': (0.7520424836601307,
#                         0.21944949448232326,
#                         0.8059967320261439,
#                         0.23207575710858588)},
#               {'type': 'Title',
#                'binary_representation': b'Aircraft Damage:',
#                'text_representation': 'Aircraft Damage:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '056c2a6808a47491d4046f2b45dd0834'},
#                'bbox': (0.5755718954248366,
#                         0.24421085819444438,
#                         0.7048039215686275,
#                         0.256837120820707)},
#               {'type': 'Title',
#                'binary_representation': b'Substantial',
#                'text_representation': 'Substantial',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '462704f78d38a6a28fa3592e8fa6a461'},
#                'bbox': (0.7520424836601307,
#                         0.24421085819444438,
#                         0.8330882352941176,
#                         0.256837120820707)},
#               {'type': 'Title',
#                'binary_representation': b'Injuries:',
#                'text_representation': 'Injuries:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '0cfd4ac7baa7afce7493243553ebd751'},
#                'bbox': (0.5755718954248366,
#                         0.2689722219065656,
#                         0.6396895424836602,
#                         0.28159848453282826)},
#               {'type': 'Title',
#                'binary_representation': b'1 Minor',
#                'text_representation': '1 Minor',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 1,
#                               'links': [],
#                               'element_id': '0e5e4b5e6f5f5f7ab4371ab8348a20cb'},
#                'bbox': (0.7520424836601307,
#                         0.2689722219065656,
#                         0.8058333333333333,
#                         0.28159848453282826)},
#               {'type': 'Title',
#                'binary_representation': b'Findings',
#                'text_representation': 'Findings',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 2,
#                               'links': [],
#                               'element_id': 'e171c2ff25b55e5a2d63d081ec3a65e2'},
#                'bbox': (0.08823529411764706,
#                         0.10092424198232319,
#                         0.16419607843137254,
#                         0.11607575713383834)},
#               {'type': 'UncategorizedText',
#                'binary_representation': b'Occurrence #1: IN FLIGHT ENCOUNTER W'
#                                         b'ITH WEATHER Phase of Operation: APPR'
#                                         b'OACH - IAF TO FAF/OUTER MARKER (IFR)',
#                'text_representation': 'Occurrence #1: IN FLIGHT ENCOUNTER WITH '
#                                       'WEATHER Phase of Operation: APPROACH - '
#                                       'IAF TO FAF/OUTER MARKER (IFR)',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'e171c2ff25b55e5a2d63d081ec3a65e2',
#                               'page_number': 2,
#                               'links': [],
#                               'element_id': '1b9e1bf33ca98b469db324ef9415cd8e'},
#                'bbox': (0.08823529411764706,
#                         0.14582449585858578,
#                         0.5737908496732026,
#                         0.17311111209595956)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'Findings 1. (F) WEATHER CONDITION - '
#                                         b'ICING CONDITIONS 2. (F) WEATHER COND'
#                                         b'ITION - DRIZZLE/MIST 3. (C) FLIGHT I'
#                                         b'NTO KNOWN ADVERSE WEATHER - CONTINUE'
#                                         b'D - PILOT IN COMMAND 4. AIRFRAME - I'
#                                         b'CE 5. (F) LEVEL OFF - NOT POSSIBLE -'
#                                         b' PILOT IN COMMAND 6. WINDOW,FLIGHT C'
#                                         b'OMPARTMENT WINDOW/WINDSHIELD - ICE 7'
#                                         b'. (F) VISUAL LOOKOUT - NOT POSSIBLE '
#                                         b'- PILOT IN COMMAND 8. AIRCRAFT/EQUIP'
#                                         b'MENT INADEQUATE - MANUFACTURER -----'
#                                         b'-----',
#                'text_representation': 'Findings 1. (F) WEATHER CONDITION - '
#                                       'ICING CONDITIONS 2. (F) WEATHER '
#                                       'CONDITION - DRIZZLE/MIST 3. (C) FLIGHT '
#                                       'INTO KNOWN ADVERSE WEATHER - CONTINUED '
#                                       '- PILOT IN COMMAND 4. AIRFRAME - ICE 5. '
#                                       '(F) LEVEL OFF - NOT POSSIBLE - PILOT IN '
#                                       'COMMAND 6. WINDOW,FLIGHT COMPARTMENT '
#                                       'WINDOW/WINDSHIELD - ICE 7. (F) VISUAL '
#                                       'LOOKOUT - NOT POSSIBLE - PILOT IN '
#                                       'COMMAND 8. AIRCRAFT/EQUIPMENT '
#                                       'INADEQUATE - MANUFACTURER ----------',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'e171c2ff25b55e5a2d63d081ec3a65e2',
#                               'page_number': 2,
#                               'links': [],
#                               'element_id': '9acdaafc269c15ba86b5f34a53afd3dd'},
#                'bbox': (0.08823529411764706,
#                         0.18980555669191912,
#                         0.6903267973856206,
#                         0.33437501146464643)},
#               {'type': 'Title',
#                'binary_representation': b'Occurrence #2: IN FLIGHT COLLISION W'
#                                         b'ITH TERRAIN/WATER Phase of Operation'
#                                         b': EMERGENCY LANDING',
#                'text_representation': 'Occurrence #2: IN FLIGHT COLLISION WITH '
#                                       'TERRAIN/WATER Phase of Operation: '
#                                       'EMERGENCY LANDING',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 2,
#                               'links': [],
#                               'element_id': '9f9d1b0aafa6600e3de7cb859f0b4467'},
#                'bbox': (0.08823529411764706,
#                         0.3510694367929293,
#                         0.5283006535947713,
#                         0.3783560434090909)},
#               {'type': 'Title',
#                'binary_representation': b'Findings 9. FLARE - NOT POSSIBLE - P'
#                                         b'ILOT IN COMMAND',
#                'text_representation': 'Findings 9. FLARE - NOT POSSIBLE - '
#                                       'PILOT IN COMMAND',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 2,
#                               'links': [],
#                               'element_id': 'af4fb5c346fd6f9423ae0052a2772915'},
#                'bbox': (0.08823529411764706,
#                         0.3950505072727272,
#                         0.42799019607843136,
#                         0.4223371138762626)},
#               {'type': 'Title',
#                'binary_representation': b'Page 2 of 7',
#                'text_representation': 'Page 2 of 7',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 2,
#                               'links': [],
#                               'element_id': '1c7fe3551107f6ef212db2fed2631f2c'},
#                'bbox': (0.08823529411764706,
#                         0.947732338510101,
#                         0.17790686274509804,
#                         0.9616212273989899)},
#               {'type': 'Title',
#                'binary_representation': b'FTW95FA129',
#                'text_representation': 'FTW95FA129',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 2,
#                               'links': [],
#                               'element_id': 'ae4ce48b0df4dd7a0f4fa1b6262818dc'},
#                'bbox': (0.8094183006535948,
#                         0.947732338510101,
#                         0.9117614379084968,
#                         0.9616212273989899)},
#               {'type': 'Title',
#                'binary_representation': b'Factual Information',
#                'text_representation': 'Factual Information',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': '49367f53d5d90d8dbc82e25b7bb52684'},
#                'bbox': (0.08823529411764706,
#                         0.09395707023989903,
#                         0.31416666666666665,
#                         0.11289646417929297)},
#               {'type': 'Title',
#                'binary_representation': b'HISTORY OF FLIGHT',
#                'text_representation': 'HISTORY OF FLIGHT',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': 'c6d02978c16c882140c8f9d742ba5160'},
#                'bbox': (0.08823529411764706,
#                         0.13011237314393947,
#                         0.2894901960784314,
#                         0.1452638882954546)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'On March 2, 1995, at 0815 central st'
#                                         b'andard time, a Cessna 208B, N9448B, '
#                                         b'was substantially damaged during a f'
#                                         b'orced landing near Ardmore, Oklahoma'
#                                         b'. The instrument rated commercial pi'
#                                         b'lot suffered minor injuries. The air'
#                                         b'plane, operating under the callsign '
#                                         b'Martinaire 633, was owned by Cessna '
#                                         b'Finance Corporation, of Wichita, Kan'
#                                         b'sas, and operated by MartinAire of D'
#                                         b'allas, Texas. Instrument meteorologi'
#                                         b'cal conditions prevailed for the 14 '
#                                         b'CFR Part 135 cargo flight.',
#                'text_representation': 'On March 2, 1995, at 0815 central '
#                                       'standard time, a Cessna 208B, N9448B, '
#                                       'was substantially damaged during a '
#                                       'forced landing near Ardmore, Oklahoma. '
#                                       'The instrument rated commercial pilot '
#                                       'suffered minor injuries. The airplane, '
#                                       'operating under the callsign Martinaire '
#                                       '633, was owned by Cessna Finance '
#                                       'Corporation, of Wichita, Kansas, and '
#                                       'operated by MartinAire of Dallas, '
#                                       'Texas. Instrument meteorological '
#                                       'conditions prevailed for the 14 CFR '
#                                       'Part 135 cargo flight.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'c6d02978c16c882140c8f9d742ba5160',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': 'ce78a523c701dfc2581e0b7fdc373e02'},
#                'bbox': (0.08823529411764706,
#                         0.15490403768939404,
#                         0.9109411764705884,
#                         0.25613509973484855)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'According to the operator, the airpl'
#                                         b'ane departed the Tulsa International'
#                                         b' Airport (TUL), at 0715 with a paylo'
#                                         b'ad of 1,300 pounds of cargo, destine'
#                                         b'd for the Ardmore Downtown Executive'
#                                         b' Airport (1F0). A weather briefing w'
#                                         b'as received and an instrument flight'
#                                         b' plan filed.',
#                'text_representation': 'According to the operator, the airplane '
#                                       'departed the Tulsa International '
#                                       'Airport (TUL), at 0715 with a payload '
#                                       'of 1,300 pounds of cargo, destined for '
#                                       'the Ardmore Downtown Executive Airport '
#                                       '(1F0). A weather briefing was received '
#                                       'and an instrument flight plan filed.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'c6d02978c16c882140c8f9d742ba5160',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': '3a071aaf1909e8af89568501b14d1db0'},
#                'bbox': (0.08823529411764706,
#                         0.26577525154040416,
#                         0.9136274509803923,
#                         0.31535858786616167)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'The pilot stated he was cleared for '
#                                         b'the NDB Runway 35 Approach to Ardmor'
#                                         b'e while level at 5,000 feet. The pil'
#                                         b'ot further stated that as he proceed'
#                                         b'ed from the VOR to the NDB for the p'
#                                         b'rocedure turn, the airplane accumula'
#                                         b'ted ice at a rapid rate. The pilot s'
#                                         b'tated that he added maximum availabl'
#                                         b'e power, as he continued to cycle th'
#                                         b'e wing/strut deicing boots.',
#                'text_representation': 'The pilot stated he was cleared for the '
#                                       'NDB Runway 35 Approach to Ardmore while '
#                                       'level at 5,000 feet. The pilot further '
#                                       'stated that as he proceeded from the '
#                                       'VOR to the NDB for the procedure turn, '
#                                       'the airplane accumulated ice at a rapid '
#                                       'rate. The pilot stated that he added '
#                                       'maximum available power, as he '
#                                       'continued to cycle the wing/strut '
#                                       'deicing boots.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'c6d02978c16c882140c8f9d742ba5160',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': '04e1556e60e10b27bd20186bf4520613'},
#                'bbox': (0.08823529411764706,
#                         0.32499873484848485,
#                         0.8802745098039216,
#                         0.391797973320707)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'The pilot stated that the airplane w'
#                                         b'as configured with flaps up, airspee'
#                                         b'd at 110 knots when he broke out int'
#                                         b'o visual conditions at approximately'
#                                         b' 400 feet AGL. The pilot further sta'
#                                         b'ted that he was unable to arrest the'
#                                         b' 400 to 500 fpm rate of descent to h'
#                                         b'old altitude. The airplane impacted '
#                                         b'in an open pasture in a nose low att'
#                                         b'itude. The nose landing gear separat'
#                                         b'ed, the mains collapsed, and the car'
#                                         b'go pod was crushed.',
#                'text_representation': 'The pilot stated that the airplane was '
#                                       'configured with flaps up, airspeed at '
#                                       '110 knots when he broke out into visual '
#                                       'conditions at approximately 400 feet '
#                                       'AGL. The pilot further stated that he '
#                                       'was unable to arrest the 400 to 500 fpm '
#                                       'rate of descent to hold altitude. The '
#                                       'airplane impacted in an open pasture in '
#                                       'a nose low attitude. The nose landing '
#                                       'gear separated, the mains collapsed, '
#                                       'and the cargo pod was crushed.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'c6d02978c16c882140c8f9d742ba5160',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': 'f6c5e39164ce58ddddc3f5aa0e59dabf'},
#                'bbox': (0.08823529411764706,
#                         0.4014381395833333,
#                         0.8966078431372548,
#                         0.4854532898484848)},
#               {'type': 'Title',
#                'binary_representation': b'PERSONNEL INFORMATION',
#                'text_representation': 'PERSONNEL INFORMATION',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': 'adec480e6277fd2895a5e4b8bb28d6d5'},
#                'bbox': (0.08823529411764706,
#                         0.4950934271969697,
#                         0.35531372549019613,
#                         0.5102449423484848)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'The pilot who is home-based at Tulsa'
#                                         b', Oklahoma, stated that he had been '
#                                         b'on duty since 2130 the previous nigh'
#                                         b't, and had flown a total of 4.2 hour'
#                                         b's during the same duty period. His l'
#                                         b'ast training session and check ride '
#                                         b'were completed on February 24, 1995.',
#                'text_representation': 'The pilot who is home-based at Tulsa, '
#                                       'Oklahoma, stated that he had been on '
#                                       'duty since 2130 the previous night, and '
#                                       'had flown a total of 4.2 hours during '
#                                       'the same duty period. His last training '
#                                       'session and check ride were completed '
#                                       'on February 24, 1995.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'adec480e6277fd2895a5e4b8bb28d6d5',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': '6623d27a7b27126368217c89e64c2477'},
#                'bbox': (0.08823529411764706,
#                         0.5198851061868687,
#                         0.8926274509803918,
#                         0.5694684425126262)},
#               {'type': 'Title',
#                'binary_representation': b'AIRCRAFT INFORMATION',
#                'text_representation': 'AIRCRAFT INFORMATION',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': '37f049b70831c8fb31b96e1e1b31fbb6'},
#                'bbox': (0.08823529411764706,
#                         0.5791085894949495,
#                         0.3344117647058824,
#                         0.5942601046464646)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'The 1988 model airplane was issued a'
#                                         b' normal category airworthiness certi'
#                                         b'ficate on September 22, 1988. The ai'
#                                         b'rplane was certified as a single pil'
#                                         b'ot aircraft, certified for flights i'
#                                         b'nto known light to moderate icing co'
#                                         b'nditions. The airplane was not equip'
#                                         b'ped with deicing boots for the nosec'
#                                         b'ap of the cargo pod or the landing g'
#                                         b'ear struts.',
#                'text_representation': 'The 1988 model airplane was issued a '
#                                       'normal category airworthiness '
#                                       'certificate on September 22, 1988. The '
#                                       'airplane was certified as a single '
#                                       'pilot aircraft, certified for flights '
#                                       'into known light to moderate icing '
#                                       'conditions. The airplane was not '
#                                       'equipped with deicing boots for the '
#                                       'nosecap of the cargo pod or the landing '
#                                       'gear struts.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': '37f049b70831c8fb31b96e1e1b31fbb6',
#                               'page_number': 3,
#                               'links': [],
#                               'element_id': '087a40af1ecd64e454e0d0ce087105b9'},
#                'bbox': (0.08823529411764706,
#                         0.6039002684974748,
#                         0.905450980392157,
#                         0.6706995069696969)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'A review of the airframe and engine '
#                                         b'records by the FAA inspector, did no'
#                                         b't reveal any anomalies, uncorrected '
#                                         b'maintenance, or overdue airworthines'
# ...
#                'bbox': (0.7140522875816994,
#                         0.5535909262626263,
#                         0.7700816993464051,
#                         0.5649545626262626)},
#               {'type': 'Title',
#                'binary_representation': b'None',
#                'text_representation': 'None',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 6,
#                               'links': [],
#                               'element_id': 'dc937b59892604f5a86ac96936cd7ff0'},
#                'bbox': (0.6294934640522876,
#                         0.6643333314772727,
#                         0.6642728758169935,
#                         0.6756969678409092)},
#               {'type': 'Title',
#                'binary_representation': b'None',
#                'text_representation': 'None',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 6,
#                               'links': [],
#                               'element_id': 'dc937b59892604f5a86ac96936cd7ff0'},
#                'bbox': (0.6294934640522876,
#                         0.6868106018560607,
#                         0.6642728758169935,
#                         0.698174238219697)},
#               {'type': 'Title',
#                'binary_representation': b'None',
#                'text_representation': 'None',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 6,
#                               'links': [],
#                               'element_id': 'dc937b59892604f5a86ac96936cd7ff0'},
#                'bbox': (0.6294934640522876,
#                         0.7092878770454546,
#                         0.6642728758169935,
#                         0.720651513409091)},
#               {'type': 'UncategorizedText',
#                'binary_representation': b'47.44889,-122.309448',
#                'text_representation': '47.44889,-122.309448',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': '425efed094764fe96041059aab7726c8',
#                               'page_number': 6,
#                               'links': [],
#                               'element_id': '574c61c32a5305c361b472e056a9ef36'},
#                'bbox': (0.6294934640522876,
#                         0.7317651474242425,
#                         0.7763022875816994,
#                         0.7431287837878788)},
#               {'type': 'Title',
#                'binary_representation': b'SEA04IA045',
#                'text_representation': 'SEA04IA045',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 6,
#                               'links': [],
#                               'element_id': 'f8283b224fbff2ea56cc580b3204499c'},
#                'bbox': (0.821145400506536,
#                         0.9510050711111111,
#                         0.9117663155392157,
#                         0.9636313337373738)},
#               {'type': 'Title',
#                'binary_representation': b'Administrative Information',
#                'text_representation': 'Administrative Information',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': 'eb881a3e85e342ce2227397c4129f5dd'},
#                'bbox': (0.08823529411764706,
#                         0.09394191973484854,
#                         0.3175882352941177,
#                         0.1090934348863637)},
#               {'type': 'Title',
#                'binary_representation': b'Investigator In Charge (IIC):',
#                'text_representation': 'Investigator In Charge (IIC):',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': 'a60d9e61c6a3888b4527066da9b37300'},
#                'bbox': (0.08823529411764706,
#                         0.12210101070707069,
#                         0.2619852941176472,
#                         0.13346464707070707)},
#               {'type': 'Title',
#                'binary_representation': b'Anderson, Orrin',
#                'text_representation': 'Anderson, Orrin',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': '00f1e752bfa9a2ee5d0afd330b2abd18'},
#                'bbox': (0.3151960684640523,
#                         0.12210101070707069,
#                         0.41175489199346405,
#                         0.13346464707070707)},
#               {'type': 'Title',
#                'binary_representation': b'Additional Participating Persons: Ha'
#                                         b'rold Hutchins; Seattle FSDO; Renton,'
#                                         b' WA',
#                'text_representation': 'Additional Participating Persons: '
#                                       'Harold Hutchins; Seattle FSDO; Renton, '
#                                       'WA',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': 'd1fa82940a22c19cae9eb358a4e75c04'},
#                'bbox': (0.08823529411764706,
#                         0.14457828108585846,
#                         0.5825931272875817,
#                         0.15594191744949482)},
#               {'type': 'Title',
#                'binary_representation': b'Original Publish Date:',
#                'text_representation': 'Original Publish Date:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': 'cd8b0287b231e50f8ea88e79a575f471'},
#                'bbox': (0.08823529411764706,
#                         0.1670555562752525,
#                         0.22451470588235298,
#                         0.17841919263888886)},
#               {'type': 'UncategorizedText',
#                'binary_representation': b'June 8, 2005',
#                'text_representation': 'June 8, 2005',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'cd8b0287b231e50f8ea88e79a575f471',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': '4d44fbdd3f2a5e2091e887b7317f8e04'},
#                'bbox': (0.3151960684640523,
#                         0.1670555562752525,
#                         0.39519606846405225,
#                         0.17841919263888886)},
#               {'type': 'Title',
#                'binary_representation': b'Note:',
#                'text_representation': 'Note:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': '1150f05446e4d34452b320c78645f5d7'},
#                'bbox': (0.08823529411764706,
#                         0.18953282665404028,
#                         0.12269117647058823,
#                         0.20089646301767664)},
#               {'type': 'Title',
#                'binary_representation': b'Investigation Docket:',
#                'text_representation': 'Investigation Docket:',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': '38800476b3b1fb33e25f11b6764821b9'},
#                'bbox': (0.08823529411764706,
#                         0.21201010184343433,
#                         0.22185294117647064,
#                         0.22337373820707068)},
#               {'type': 'Title',
#                'binary_representation': b'https://data.ntsb.gov/Docket?Project'
#                                         b'ID=58851',
#                'text_representation': 'https://data.ntsb.gov/Docket?ProjectID=58851',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': 'cc0e272bb9781513b913fdb6decadb95'},
#                'bbox': (0.3151960684640523,
#                         0.21201010184343433,
#                         0.622004891993464,
#                         0.22337373820707068)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'The National Transportation Safety B'
#                                         b'oard (NTSB), established in 1967, is'
#                                         b' an independent federal agency manda'
#                                         b'ted by Congress through the Independ'
#                                         b'ent Safety Board Act of 1974 to inve'
#                                         b'stigate transportation accidents, de'
#                                         b'termine the probable causes of the a'
#                                         b'ccidents, issue safety recommendatio'
#                                         b'ns, study transportation safety issu'
#                                         b'es, and evaluate the safety effectiv'
#                                         b'eness of government agencies involve'
#                                         b'd in transportation. The NTSB makes '
#                                         b'public its actions and decisions thr'
#                                         b'ough accident reports, safety studie'
#                                         b's, special investigation reports, sa'
#                                         b'fety recommendations, and statistica'
#                                         b'l reviews.',
#                'text_representation': 'The National Transportation Safety '
#                                       'Board (NTSB), established in 1967, is '
#                                       'an independent federal agency mandated '
#                                       'by Congress through the Independent '
#                                       'Safety Board Act of 1974 to investigate '
#                                       'transportation accidents, determine the '
#                                       'probable causes of the accidents, issue '
#                                       'safety recommendations, study '
#                                       'transportation safety issues, and '
#                                       'evaluate the safety effectiveness of '
#                                       'government agencies involved in '
#                                       'transportation. The NTSB makes public '
#                                       'its actions and decisions through '
#                                       'accident reports, safety studies, '
#                                       'special investigation reports, safety '
#                                       'recommendations, and statistical '
#                                       'reviews.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'cc0e272bb9781513b913fdb6decadb95',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': 'f7832a580c5ef5e4501d12c153083bba'},
#                'bbox': (0.25196078478758166,
#                         0.27281059941919183,
#                         0.7502990200816996,
#                         0.393285349760101)},
#               {'type': 'NarrativeText',
#                'binary_representation': b'The Independent Safety Board Act, as'
#                                         b' codified at 49 U.S.C. Section 1154('
#                                         b'b), precludes the admission into evi'
#                                         b'dence or use of any part of an NTSB '
#                                         b'report related to an incident or acc'
#                                         b'ident in a civil action for damages '
#                                         b'resulting from a matter mentioned in'
#                                         b' the report. A factual report that m'
#                                         b'ay be admissible under 49 U.S.C.'
#                                         b' \xc2\xa7 1154(b) is available here.',
#                'text_representation': 'The Independent Safety Board Act, as '
#                                       'codified at 49 U.S.C. Section 1154(b), '
#                                       'precludes the admission into evidence '
#                                       'or use of any part of an NTSB report '
#                                       'related to an incident or accident in a '
#                                       'civil action for damages resulting from '
#                                       'a matter mentioned in the report. A '
#                                       'factual report that may be admissible '
#                                       'under 49 U.S.C. § 1154(b) is available '
#                                       'here.',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'parent_id': 'cc0e272bb9781513b913fdb6decadb95',
#                               'page_number': 7,
#                               'links': [{'text': 'here',
#                                          'url': 'http://data.ntsb.gov/carol-repgen/api/Aviation/ReportMain/GenerateFactualReport/58851/pdf',
#                                          'start_index': 344}],
#                               'element_id': '964160e9ff92a0eccb5ac22c3c0a146b'},
#                'bbox': (0.25196078478758166,
#                         0.4091994864772728,
#                         0.7472843141993465,
#                         0.4751186786237374)},
#               {'type': 'Title',
#                'binary_representation': b'Page 7 of 7',
#                'text_representation': 'Page 7 of 7',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': '4a43556995bdf31fa9dfa94f2387ba90'},
#                'bbox': (0.08823529411764706,
#                         0.9510050711111111,
#                         0.17073529411764707,
#                         0.9636313337373738)},
#               {'type': 'Title',
#                'binary_representation': b'SEA04IA045',
#                'text_representation': 'SEA04IA045',
#                'properties': {'filename': '',
#                               'filetype': 'application/pdf',
#                               'page_number': 7,
#                               'links': [],
#                               'element_id': 'f8283b224fbff2ea56cc580b3204499c'},
#                'bbox': (0.821145400506536,
#                         0.9510050711111111,
#                         0.9117663155392157,
#                         0.9636313337373738)}]}
