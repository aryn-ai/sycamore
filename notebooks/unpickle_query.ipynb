# %% [markdown]
# This notebook allows visualization of a Sycamore Query as a pandas dataframe. Can see the state of the DocSet after each map function given a query ID and the directory of pickled DocSets. Options to view entire dataframe or a "summarized" version.

# %%
import os
import pickle
import pandas as pd

# %%
QUERY_ID = "eb7c6d5b-9a77-49b1-abf6-afb4fe5cc41a"
BASE_DIR = f"{os.path.dirname(os.getcwd())}/lib/sycamore/sycamore/query/luna_traces"
BASE_PROPS = set(
    [
        "filename",
        "filetype",
        "page_number",
        "page_numbers",
        "links",
        "element_id",
        "parent_id",
        "_schema",
        "_schema_class",
        "entity",
    ]
)
DISPLAY_ENTIRE_DF = False

# %%
# Iterate through NODE_IDS and collect properties from unpickled objects
for id in sorted(os.listdir(f"{BASE_DIR}/{QUERY_ID}")):

    # Initialize a list to hold the data
    data_list = []
    directory = f"{BASE_DIR}/{QUERY_ID}/{id}"

    for filename in os.listdir(directory):
        f = os.path.join(directory, filename)
        if os.path.isfile(f):
            with open(f, "rb") as file:
                doc = pickle.load(file)
                doc_list = doc.properties["entity"]

                # print(doc.properties['LlmFilterOutput'])

                for p in doc.properties:
                    if p not in BASE_PROPS:
                        try:
                            doc_list[p] = doc.properties[p]
                        except:
                            doc_list[p] = None

                data_list.append(doc_list)

    df = pd.DataFrame(data_list)

    print(f"DOCSET AFTER NODE {id}:\n-")
    # print(f'{len(df['path'].unique())} unique paths\n-' )
    print(f"{len(df)} documents\n--------------------")

    if DISPLAY_ENTIRE_DF:
        with pd.option_context(
            "display.max_rows", None, "display.max_columns", None
        ):  # more options can be specified also
            display(df)

    else:
        display(df)
# Out:
# DOCSET AFTER NODE 1:
# -
# 480 documents
# --------------------
#                            location                    dateAndTime  \
# 0            Eagle River, Wisconsin  January 25, 2023, 13:00 Local
# 1                     Kenai, Alaska   January 2, 2023, 14:57 Local
# 2    Atlantic Ocean, Atlantic Ocean     January 3, 2023, 16:22 UTC
# 3            Dallesport, Washington  January 29, 2023, 12:30 Local
# 4                    Kingfisher, OK        January 16, 2023, Local
# ..                              ...                            ...
# 475               Rich County, Utah  January 24, 2023, 17:45 Local
# 476          Eagle River, Wisconsin  January 25, 2023, 13:00 Local
# 477              Opa-locka, Florida   January 3, 2023, 12:35 Local
# 478                   Kenai, Alaska   January 2, 2023, 14:57 Local
# 479                Yelm, Washington  January 12, 2023, 13:00 Local
#
#                       aircraft                       flightConductedUnder  \
# 0                   Cessna 120       Part 91: General aviation - Personal
# 1              Piper PA-18-150       Part 91: General aviation - Personal
# 2                  Cessna 340A       Part 91: General aviation - Personal
# 3    CUB CRAFTERS INC CC18-180  Part 91: General aviation - Instructional
# 4             Piper PA-32-301T  Part 91: General aviation - Instructional
# ..                         ...                                        ...
# 475                  Beech C23       Part 91: General aviation - Personal
# 476                 Cessna 120       Part 91: General aviation - Personal
# 477                Cessna 172N  Part 91: General aviation - Instructional
# 478            Piper PA-18-150       Part 91: General aviation - Personal
# 479               Beech 95-C55       Part 91: General aviation - Personal
#
#     accidentNumber registration injuries aircraftDamage         day  \
# 0       CEN23LA098       N73034   1 None    Substantial  2023-01-25
# 1       ANC23LA011         N94X  1 Minor    Substantial  2023-01-02
# 2       ERA23LA101       N824BC   4 None    Substantial  2023-01-03
# 3       WPR23LA101       N127DT   2 None    Substantial  2023-01-29
# 4       CEN23FA079       N8266D  2 Fatal      Destroyed  2023-01-16
# ..             ...          ...      ...            ...         ...
# 475     WPR23LA099        N23FD   1 None    Substantial  2023-01-24
# 476     CEN23LA098       N73034   1 None    Substantial  2023-01-25
# 477     ERA23LA104       N2354E   2 None    Substantial  2023-01-03
# 478     ANC23LA011         N94X  1 Minor    Substantial  2023-01-02
# 479     WPR23LA089        N225V   1 None    Substantial  2023-01-12
#
#                     isoDateTime                          path  \
# 0          2023-01-25T13:00:00Z  s3://aryn-public/ntsb/18.pdf
# 1          2023-01-02T14:57:00Z  s3://aryn-public/ntsb/96.pdf
# 2    2023-01-03T16:22:00+00:00Z  s3://aryn-public/ntsb/92.pdf
# 3          2023-01-29T12:30:00Z   s3://aryn-public/ntsb/6.pdf
# 4          2023-01-16T00:00:00Z  s3://aryn-public/ntsb/54.pdf
# ..                          ...                           ...
# 475        2023-01-24T17:45:00Z  s3://aryn-public/ntsb/20.pdf
# 476        2023-01-25T13:00:00Z  s3://aryn-public/ntsb/18.pdf
# 477        2023-01-03T12:35:00Z  s3://aryn-public/ntsb/94.pdf
# 478        2023-01-02T14:57:00Z  s3://aryn-public/ntsb/96.pdf
# 479        2023-01-12T13:00:00Z  s3://aryn-public/ntsb/66.pdf
#
#     _autogen_LlmFilterOutput
# 0                          3
# 1                          0
# 2                          1
# 3                          1
# 4                          1
# ..                       ...
# 475                        2
# 476                        2
# 477                        0
# 478                        1
# 479                        5
#
# [480 rows x 12 columns]
