# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sycamore.data import Document, HierarchicalDocument
from sycamore.llms import OpenAI, OpenAIModels
from sycamore.connectors.file.file_scan import JsonManifestMetadataProvider
from sycamore.transforms.partition import ArynPartitioner
from sycamore.utils.time_trace import timetrace

import sycamore
import pickle
import json
import sys
import pandas as pd
import csv
import os
from pathlib import Path

from sycamore.utils.cache import DiskCache
ctx = sycamore.init() 
llm = OpenAI(OpenAIModels.GPT_4O, cache=DiskCache("/home/ritam/sycamore/ritam-scripts/llm_cache"))

# %%
def unpickle_doc(pdoc: Document) -> list[Document]:
    doc = pickle.loads(pdoc.binary_representation)
    return [doc]

path = Path('ntsb_parsed_1').resolve()
pickled_docset = ctx.read.binary(str(path), binary_format="pickle")
ds = pickled_docset.flat_map(unpickle_doc)

# %%
from sycamore.transforms.extract_document_structure import StructureBySection, StructureByDocument
from sycamore.transforms.extract_graph_entities import EntityExtractor
from sycamore.transforms.extract_graph_relationships import RelationshipExtractor
from pydantic import BaseModel, Field
import boto3


class Report(BaseModel):
    ID: str = Field(description="This ID can be found under either Accident Number, Incident Number, or Occurance Number")

class Aircraft(BaseModel):
    registration: str
    make: str
    model: str

class INVOLVED_AIRCRAFT(BaseModel):
    start: Report
    end: Aircraft

ENTITY_DEFAULT_PROMPT = """
    -Instructions-
    You are a information extraction system.

    You will be given a sequence of data in different formats(text, table, Section-header) in order.
    Your job is to extract entities from the text input that match the entity schemas provided. Each entity
    and property extracted should directly reference part of the text input provided.

    """

RELATIONSHIP_DEFAULT_PROMPT = """
    -Goal-
    You are a helpful information extraction system.

    You will be given a sequence of data in different formats(text, table, Section-header) in order.
    Your job is to extract relationships that map between entities that have already been extracted from this text.

    """


ds_resolved = (
    ds.extract_document_structure(StructureBySection)
    .extract_graph_entities([EntityExtractor(llm=llm, entities=[Report, Aircraft], prompt=ENTITY_DEFAULT_PROMPT)])
    .extract_graph_relationships([RelationshipExtractor(llm=llm, relationships=[INVOLVED_AIRCRAFT], prompt=RELATIONSHIP_DEFAULT_PROMPT)])
    .materialize(path="/tmp/extract_graph", source_mode=sycamore.MATERIALIZE_USE_STORED)
    .resolve_graph_entities(resolvers=[], resolve_duplicates=False)
    #.explode()
)

docs = ds_resolved.take_all()

#URI = "bolt://localhost:11001"
#AUTH = ("neo4j", "koala-stereo-comedy-spray-figure-6974")


# URI = 'neo4j+s://adc13803.databases.neo4j.io'
# AUTH = ('neo4j', 'bbOoM_jRSl9bfiN5EfRTam4QeJFTAWU34Jvv-6soQfM')
# DATABASE = "neo4j"
# IMPORT_DIR = "/home/ritam/neo4j/import"
# s3_session = boto3.session.Session()

# ds.write.neo4j(uri=URI,auth=AUTH,database=DATABASE,import_dir=IMPORT_DIR, use_auradb=True, s3_session=s3_session)
# Out:
# 2024-09-06 22:33:46,560	INFO worker.py:1740 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 2024-09-06 22:33:50,237	INFO streaming_executor.py:112 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-09-06_22-33-42_674101_2510893/logs/ray-data
# 2024-09-06 22:33:50,239	INFO streaming_executor.py:113 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadBinary] -> TaskPoolMapOperator[Map(BinaryScan._to_document)->MapBatches(unpickle_doc)->MapBatches(extract)->MapBatches(extract)->MapBatches(extract)->MapBatches(materialize)->MapBatches(_aggregate_section_nodes)]
# - ReadBinary->SplitBlocks(16) 1:   0%|          | 0/1 [00:00<?, ?it/s]
# - Map(BinaryScan._to_document)->MapBatches(unpickle_doc)->MapBatches(extract)->MapBatches(extract)->MapBatches…
# Running 0:   0%|          | 0/1 [00:00<?, ?it/s]
# (Map(BinaryScan._to_document)->MapBatches(unpickle_doc)->MapBatches(extract)->MapBatches(extract)->MapBatches(extract)->MapBatches(materialize)->MapBatches(_aggregate_section_nodes) pid=2511088) Unrecognized extenstion pickle; using application/pickle
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725662034.662199 2510893 config.cc:230] gRPC experiments enabled: call_status_override_on_cancellation, event_engine_dns, event_engine_listener, http2_stats_fix, monitoring_experiment, pick_first_new, trace_record_callops, work_serializer_clears_time_cache
# 2024-09-06 22:33:54,693	INFO dataset.py:2370 -- Tip: Use `take_batch()` instead of `take() / show()` to return records in pandas or numpy batch format.
# 2024-09-06 22:33:54,700	INFO streaming_executor.py:112 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-09-06_22-33-42_674101_2510893/logs/ray-data
# 2024-09-06 22:33:54,702	INFO streaming_executor.py:113 -- Execution plan of Dataset: InputDataBuffer[Input] -> AllToAllOperator[Aggregate] -> LimitOperator[limit=1]
# - Aggregate 1:   0%|          | 0/16 [00:00<?, ?it/s]
# Shuffle Map 2:   0%|          | 0/16 [00:00<?, ?it/s]
# Shuffle Reduce 3:   0%|          | 0/16 [00:00<?, ?it/s]
# - limit=1 4:   0%|          | 0/16 [00:00<?, ?it/s]
# Running 0:   0%|          | 0/16 [00:00<?, ?it/s]
# 2024-09-06 22:33:54,941	ERROR exceptions.py:73 -- Exception occurred in Ray Data or Ray Core internal code. If you continue to see this error, please open an issue on the Ray project GitHub page with the full stack trace below: https://github.com/ray-project/ray/issues/new/choose
# 2024-09-06 22:33:54,960	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::reduce() (pid=2511088, ip=172.31.9.237)
#   File "/home/ritam/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/_internal/planner/exchange/aggregate_task_spec.py", line 70, in reduce
#     return BlockAccessor.for_block(mapper_outputs[0]).aggregate_combined_blocks(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ritam/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/_internal/arrow_block.py", line 658, in aggregate_combined_blocks
#     accumulators[i] = aggs[i].merge(
#                       ^^^^^^^^^^^^^^
#   File "/home/ritam/sycamore/lib/sycamore/sycamore/transforms/resolve_graph_entities.py", line 151, in merge
#     check_if_bad(nodes2)
#   File "/home/ritam/sycamore/lib/sycamore/sycamore/transforms/resolve_graph_entities.py", line 220, in check_if_bad
#     assert isinstance(rel, dict), f"{json.dumps(node['relationships'], indent=2)}"
# AssertionError: {
#   "1c69646b-6130-4389-860b-b977c958caea": {
#     "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
#     "END_LABEL": "Aircraft",
#     "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
#     "START_LABEL": "Report",
#     "TYPE": "INVOLVED_AIRCRAFT",
#     "properties": {}
#   },
#   "26e7c513-73a3-4373-8e17-c38d2a12afbb": null,
#   "6890231b-3b2f-430d-97d2-1f47f609c7fe": null,
#   "d113493e-58c8-43f8-9c56-c1397ec586ec": {
#     "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
#     "END_LABEL": "Aircraft",
#     "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
#     "START_LABEL": "SECTION",
#     "TYPE": "CONTAINS",
#     "properties": {}
#   }
# }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {}
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:OUTPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)
# ---------------------------------------------------------------------------
# SystemException                           Traceback (most recent call last)
# SystemException:
#
# The above exception was the direct cause of the following exception:
#
# RayTaskError(AssertionError)              Traceback (most recent call last)
# Cell In[4], line 45
#      20 ENTITY_DEFAULT_PROMPT = """
#      21     -Instructions-
#      22     You are a information extraction system.
#    (...)
#      27
#      28     """
#      30 RELATIONSHIP_DEFAULT_PROMPT = """
#      31     -Goal-
#      32     You are a helpful information extraction system.
#    (...)
#      36
#      37     """
#      40 ds_resolved = (
#      41     ds.extract_document_structure(StructureBySection)
#      42     .extract_graph_entities([EntityExtractor(llm=llm, entities=[Report, Aircraft], prompt=ENTITY_DEFAULT_PROMPT)])
#      43     .extract_graph_relationships([RelationshipExtractor(llm=llm, relationships=[INVOLVED_AIRCRAFT], prompt=RELATIONSHIP_DEFAULT_PROMPT)])
#      44     .materialize(path="/tmp/extract_graph", source_mode=sycamore.MATERIALIZE_USE_STORED)
# ---> 45     .resolve_graph_entities(resolvers=[], resolve_duplicates=False)
#      46     #.explode()
#      47 )
#      49 docs = ds_resolved.take_all()
#      51 #URI = "bolt://localhost:11001"
#      52 #AUTH = ("neo4j", "koala-stereo-comedy-spray-figure-6974")
#      53
#    (...)
#      60
#      61 # ds.write.neo4j(uri=URI,auth=AUTH,database=DATABASE,import_dir=IMPORT_DIR, use_auradb=True, s3_session=s3_session)
#
# File ~/sycamore/lib/sycamore/sycamore/docset.py:670, in DocSet.resolve_graph_entities(self, resolvers, resolve_duplicates, **kwargs)
#     667         return self._ds
#     669 entity_resolver = ResolveEntities(resolvers=resolvers, resolve_duplicates=resolve_duplicates)
# --> 670 entities = entity_resolver.resolve(self)  # resolve entities
#     671 entities_clean = CleanTempNodes(Wrapper(entities))  # cleanup temp objects
#     672 return DocSet(self.context, entities_clean)
#
# File ~/sycamore/lib/sycamore/sycamore/transforms/resolve_graph_entities.py:41, in ResolveEntities.resolve(self, docset)
#      39 dataset = docset.plan.execute().materialize()
#      40 # Perform ray aggregate over dataset
# ---> 41 nodes = self._aggregate_document_nodes(dataset)
#      43 if self.resolve_duplicates:
#      44     remap = {}
#
# File ~/sycamore/lib/sycamore/sycamore/transforms/resolve_graph_entities.py:172, in ResolveEntities._aggregate_document_nodes(dataset)
#     167     return copy.deepcopy(nodes)
#     169 aggregation = AggregateFn(
#     170     init=lambda group_key: dict(), accumulate_row=accumulate_row, merge=merge, finalize=finalize, name="nodes"
#     171 )
# --> 172 result = dataset.aggregate(aggregation)["nodes"]
#     173 return result
#
# File ~/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/dataset.py:1917, in Dataset.aggregate(self, *aggs)
#    1880 @AllToAllAPI
#    1881 @ConsumptionAPI
#    1882 def aggregate(self, *aggs: AggregateFn) -> Union[Any, Dict[str, Any]]:
#    1883     """Aggregate values using one or more functions.
#    1884
#    1885     Use this method to compute metrics like the product of a column.
#    (...)
#    1915         A ``dict`` where each each value is an aggregation for a given column.
#    1916     """
# -> 1917     ret = self.groupby(None).aggregate(*aggs).take(1)
#    1918     return ret[0] if len(ret) > 0 else None
#
# File ~/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/dataset.py:2377, in Dataset.take(self, limit)
#    2374 output = []
#    2376 limited_ds = self.limit(limit)
# -> 2377 for row in limited_ds.iter_rows():
#    2378     output.append(row)
#    2379     if len(output) >= limit:
#
# File ~/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/iterator.py:245, in DataIterator.iter_rows.<locals>._wrapped_iterator()
#     244 def _wrapped_iterator():
# --> 245     for batch in batch_iterable:
#     246         batch = BlockAccessor.for_block(BlockAccessor.batch_to_block(batch))
#     247         for row in batch.iter_rows(public_row_format=True):
#
# File ~/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/iterator.py:162, in DataIterator.iter_batches.<locals>._create_iterator()
#     157 time_start = time.perf_counter()
#     158 # Iterate through the dataset from the start each time
#     159 # _iterator_gen is called.
#     160 # This allows multiple iterations of the dataset without
#     161 # needing to explicitly call `iter_batches()` multiple times.
# --> 162 block_iterator, stats, blocks_owned_by_consumer = self._to_block_iterator()
#     164 iterator = iter(
#     165     iter_batches(
#     166         block_iterator,
#    (...)
#     177     )
#     178 )
#     180 dataset_tag = self._get_dataset_tag()
#
# File ~/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/_internal/iterator/iterator_impl.py:33, in DataIteratorImpl._to_block_iterator(self)
#      25 def _to_block_iterator(
#      26     self,
#      27 ) -> Tuple[
#    (...)
#      30     bool,
#      31 ]:
#      32     ds = self._base_dataset
# ---> 33     block_iterator, stats, executor = ds._plan.execute_to_iterator()
#      34     ds._current_executor = executor
#      35     return block_iterator, stats, False
#
# File ~/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/exceptions.py:86, in omit_traceback_stdout.<locals>.handle_trace(*args, **kwargs)
#      84     raise e.with_traceback(None)
#      85 else:
# ---> 86     raise e.with_traceback(None) from SystemException()
#
# RayTaskError(AssertionError): ray::reduce() (pid=2511088, ip=172.31.9.237)
#   File "/home/ritam/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/_internal/planner/exchange/aggregate_task_spec.py", line 70, in reduce
#     return BlockAccessor.for_block(mapper_outputs[0]).aggregate_combined_blocks(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ritam/.cache/pypoetry/virtualenvs/sycamore-monorepo-2qWDk4xs-py3.11/lib/python3.11/site-packages/ray/data/_internal/arrow_block.py", line 658, in aggregate_combined_blocks
#     accumulators[i] = aggs[i].merge(
#                       ^^^^^^^^^^^^^^
#   File "/home/ritam/sycamore/lib/sycamore/sycamore/transforms/resolve_graph_entities.py", line 151, in merge
#     check_if_bad(nodes2)
#   File "/home/ritam/sycamore/lib/sycamore/sycamore/transforms/resolve_graph_entities.py", line 220, in check_if_bad
#     assert isinstance(rel, dict), f"{json.dumps(node['relationships'], indent=2)}"
# AssertionError: {
#   "1c69646b-6130-4389-860b-b977c958caea": {
#     "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
#     "END_LABEL": "Aircraft",
#     "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
#     "START_LABEL": "Report",
#     "TYPE": "INVOLVED_AIRCRAFT",
#     "properties": {}
#   },
#   "26e7c513-73a3-4373-8e17-c38d2a12afbb": null,
#   "6890231b-3b2f-430d-97d2-1f47f609c7fe": null,
#   "d113493e-58c8-43f8-9c56-c1397ec586ec": {
#     "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
#     "END_LABEL": "Aircraft",
#     "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
#     "START_LABEL": "SECTION",
#     "TYPE": "CONTAINS",
#     "properties": {}
#   }
# }
#            "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {}
# (map pid=2511088) ERROR:root:OUTPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {}
# (map pid=2511088) ERROR:root:OUTPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {}
# (map pid=2511088) ERROR:root:OUTPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {}
# (map pid=2511088) ERROR:root:OUTPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (map pid=2511088) ERROR:root:INPUT ACCUMULATE: {}
# (map pid=2511088) ERROR:root:OUTPUT ACCUMULATE: {
# (map pid=2511088)   "Aircraft": {
# (map pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       },
# (map pid=2511088)       {
# (map pid=2511088)         "type": "extracted",
# (map pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)         "properties": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         },
# (map pid=2511088)         "label": "Aircraft",
# (map pid=2511088)         "relationships": {
# (map pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (map pid=2511088)             "TYPE": "CONTAINS",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (map pid=2511088)             "START_LABEL": "SECTION",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           },
# (map pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (map pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (map pid=2511088)             "properties": {},
# (map pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (map pid=2511088)             "START_LABEL": "Report",
# (map pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (map pid=2511088)             "END_LABEL": "Aircraft"
# (map pid=2511088)           }
# (map pid=2511088)         },
# (map pid=2511088)         "raw_entity": {
# (map pid=2511088)           "registration": "N/A",
# (map pid=2511088)           "make": "N/A",
# (map pid=2511088)           "model": "N/A"
# (map pid=2511088)         }
# (map pid=2511088)       }
# (map pid=2511088)     ]
# (map pid=2511088)   }
# (map pid=2511088) }
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:OUTPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {}
# (reduce pid=2511088) ERROR:root:INPUT MERGE: {
# (reduce pid=2511088)   "Aircraft": {
# (reduce pid=2511088)     "a55bd63b5d420fb34140005d40f0c5df0b2acb7a92ea93995793da8012880d00": [
# (reduce pid=2511088)       {
# (reduce pid=2511088)         "doc_id": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (reduce pid=2511088)         "label": "Aircraft",
# (reduce pid=2511088)         "properties": {
# (reduce pid=2511088)           "make": "N/A",
# (reduce pid=2511088)           "model": "N/A",
# (reduce pid=2511088)           "registration": "N/A"
# (reduce pid=2511088)         },
# (reduce pid=2511088)         "raw_entity": {
# (reduce pid=2511088)           "make": "N/A",
# (reduce pid=2511088)           "model": "N/A",
# (reduce pid=2511088)           "registration": "N/A"
# (reduce pid=2511088)         },
# (reduce pid=2511088)         "relationships": {
# (reduce pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": {
# (reduce pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (reduce pid=2511088)             "END_LABEL": "Aircraft",
# (reduce pid=2511088)             "START_ID": "ae8e2674-4f79-443e-873d-e665d5f1b1b4",
# (reduce pid=2511088)             "START_LABEL": "Report",
# (reduce pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (reduce pid=2511088)             "properties": {}
# (reduce pid=2511088)           },
# (reduce pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": null,
# (reduce pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": null,
# (reduce pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": {
# (reduce pid=2511088)             "END_ID": "57c7d4c5-7a53-4852-8296-25f6560da022",
# (reduce pid=2511088)             "END_LABEL": "Aircraft",
# (reduce pid=2511088)             "START_ID": "3beff522-9474-4ff3-bc14-2020ed6ad8b6",
# (reduce pid=2511088)             "START_LABEL": "SECTION",
# (reduce pid=2511088)             "TYPE": "CONTAINS",
# (reduce pid=2511088)             "properties": {}
# (reduce pid=2511088)           }
# (reduce pid=2511088)         },
# (reduce pid=2511088)         "type": "extracted"
# (reduce pid=2511088)       },
# (reduce pid=2511088)       {
# (reduce pid=2511088)         "doc_id": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (reduce pid=2511088)         "label": "Aircraft",
# (reduce pid=2511088)         "properties": {
# (reduce pid=2511088)           "make": "N/A",
# (reduce pid=2511088)           "model": "N/A",
# (reduce pid=2511088)           "registration": "N/A"
# (reduce pid=2511088)         },
# (reduce pid=2511088)         "raw_entity": {
# (reduce pid=2511088)           "make": "N/A",
# (reduce pid=2511088)           "model": "N/A",
# (reduce pid=2511088)           "registration": "N/A"
# (reduce pid=2511088)         },
# (reduce pid=2511088)         "relationships": {
# (reduce pid=2511088)           "1c69646b-6130-4389-860b-b977c958caea": null,
# (reduce pid=2511088)           "26e7c513-73a3-4373-8e17-c38d2a12afbb": {
# (reduce pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (reduce pid=2511088)             "END_LABEL": "Aircraft",
# (reduce pid=2511088)             "START_ID": "804bcebe-36be-4d71-af43-39be5efccf15",
# (reduce pid=2511088)             "START_LABEL": "Report",
# (reduce pid=2511088)             "TYPE": "INVOLVED_AIRCRAFT",
# (reduce pid=2511088)             "properties": {}
# (reduce pid=2511088)           },
# (reduce pid=2511088)           "6890231b-3b2f-430d-97d2-1f47f609c7fe": {
# (reduce pid=2511088)             "END_ID": "1b7b74c2-36fa-4fde-a9e0-9d8eeaad8d1c",
# (reduce pid=2511088)             "END_LABEL": "Aircraft",
# (reduce pid=2511088)             "START_ID": "7c586a1d-505a-4e30-a114-75224c67d286",
# (reduce pid=2511088)             "START_LABEL": "SECTION",
# (reduce pid=2511088)             "TYPE": "CONTAINS",
# (reduce pid=2511088)             "properties": {}
# (reduce pid=2511088)           },
# (reduce pid=2511088)           "d113493e-58c8-43f8-9c56-c1397ec586ec": null
# (reduce pid=2511088)         },
# (reduce pid=2511088)         "type": "extracted"
# (reduce pid=2511088)       }
# (reduce pid=2511088)     ]
# (reduce pid=2511088)   }
# (reduce pid=2511088) }

# %%
class Report(BaseModel):
    Title: str

class Drug(BaseModel):
    name:
    chemical_compisition:
    price:
    time_to_develop:


class Aircraft(BaseModel):
    registration: str
    make: str
    model: str

class INVOLVED_AIRCRAFT(BaseModel):
    start: Report
    end: Aircraft

# %%
for doc in docs:
    if "nodes" not in doc["properties"]:
        continue
    print(json.dumps(doc["properties"]["nodes"], indent=2))
    # for label, hashes in doc["properties"]["nodes"].items():
    #     print(label)
    #     for hash, node in hashes.items():
    #         uuid = set()
    #         rels = set()
    #         for rel_uuid, rel in node["relationships"].items():
    #             assert rel_uuid not in uuid
    #             assert json.dumps(rel) not in rels
    #             uuid.add(json.dumps(rel_uuid))
    #             rels.add(json.dumps(rel))
    #             print(rel_uuid)

# %%
for doc in docs:
    for section in doc.children:
        for label, hashes in section["properties"]["nodes"].items():
            for hash, node in hashes.items():
                uuid = set()
                rels = set()
                for rel_uuid, rel in node["relationships"].items():
                    assert rel_uuid not in uuid
                    assert json.dumps(rel) not in rels
                    uuid.add(json.dumps(rel_uuid))
                    rels.add(json.dumps(rel))
                    print(rel_uuid)

# %%
for doc in docs:
    for section in doc.children:
        if section.type == "extracted":
            print(json.dumps(section.data["relationships"], indent=2))

# %%
for doc in docs:
    for section in doc.children:
        if section.type == "extracted":
            print(json.dumps(section.data["relationships"], indent=2))
        #print(section)
        # if "EXTRACTED_NODES" in section["properties"]:
        #     for child in section.children:
        #         print(child)
        #         for rel_uuid, rel in child["relationships"].items():
        #             print(rel_uuid)
        #             print(rel)
        # if "nodes" not in section["properties"]:
        #     continue
        # for label, hashes in section["properties"]["nodes"].items():
        #     for hash, node in hashes.items():
        #         for rel_uuid, rel in node["relationships"].items():
        #             print(rel_uuid)
                    # print(rel)
    #for section in doc.children:
    #print(json.dumps(section["properties"]["nodes"], indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for doc in docs:
#       2     for section in doc.children:
#       3         if section.type == "extracted":
#
# NameError: name 'docs' is not defined
